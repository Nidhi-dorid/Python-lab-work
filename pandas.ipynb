# %% [markdown]
# <a href="https://colab.research.google.com/github/Nidhi-dorid/Python-lab-work/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
list =['a','b','c','d']
df=pd.DataFrame(list)
print(df)
# Out:
#    0
# 0  a
# 1  b
# 2  c
# 3  d

# %%
import pandas as pd
list =['a','b','c','d']
df=pd.DataFrame(list,columns=['tabular form'])
print(df)
# Out:
#   tabular form
# 0            a
# 1            b
# 2            c
# 3            d

# %%
pip install tabulate

# %%
from tabulate import tabulate
print(tabulate([['Aditi',19],['Anmol',16],['Bhavya',19]],headers=["Name",'Age']))

# %%
from tabulate import tabulate
print(tabulate([["a"],[2],[6],[7]],headers=['random']))

# %%
pip install texttable

# %%
from texttable import Texttable
t=Texttable()
t.add_rows([['Aditi',19],['Anmol',16],['Bhavya',19]])
print(t.draw())

# %%
pip install terminaltables

# %% [markdown]
# from terminaltables import AsciiTable
#
# *   List item
# *   List item
#
#
# data=[['Aditi',19],['Anmol',16],['Bhavya',19]]
# table=AsciiTable(data)
# print(table.table)

# %%
from terminaltables import AsciiTable
data=[['Aditi',19],['Anmol',16],['Bhavya',19]]
table=AsciiTable(data,title="dft")
table.justfy='center'
table.inner_row_border=True
print(table.table)

# %%
import pandas as pd
t={"Name":['a','b','c','d'],
   "age":[23,34,45,67]
   }
df=pd.DataFrame(t)
print(df)

# %%
result_type=df['age']
result_type

# %%
selected_data = df[df['age'] >=2]
print(selected_data)

# %%
import pandas as pd
employees=[("stuti",28,'varanasi',20000),
           ("saumya",32,'delhi',25000),
           ('aaditya',25,'Mumbai',40000),
           ('saumya',32,'delhi',35000),
           ('saumya',32,'delhi',30000),
           ('saumya',32,'mumbai',20000),
           ('saumya',32,'delhi',35000),
           ('aaditya',40,'dehradun',24000),
           ('seema',32,'delhi',70000),
           ]
df=pd.DataFrame(employees,columns=['Name','age','city','salary'])
df
# Out:
#       Name  age      city  salary
# 0    stuti   28  varanasi   20000
# 1   saumya   32     delhi   25000
# 2  aaditya   25    Mumbai   40000
# 3   saumya   32     delhi   35000
# 4   saumya   32     delhi   30000
# 5   saumya   32    mumbai   20000
# 6   saumya   32     delhi   35000
# 7  aaditya   40  dehradun   24000
# 8    seema   32     delhi   70000

# %%
df.set_index('Name',inplace=True)
result=df.loc[["stuti",'seema'],
              ['city','salary']]
result
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-1eea2c8be77b> in <cell line: 1>()
# ----> 1 df.set_index('Name',inplace=True)
#       2 result=df.loc[["stuti",'seema'],
#       3               ['city','salary']]
#       4 result
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    6010
#    6011         if missing:
# -> 6012             raise KeyError(f"None of {missing} are in the columns")
#    6013
#    6014         if inplace:
#
# ...

# %%
import pandas as pd
data=pd.Series([1,1,1,2,3,3,3,4,4,5])
data.value_counts(sort=False)
# Out:
# 1    3
# 2    1
# 3    3
# 4    2
# 5    1
# dtype: int64

# %%
import pandas as pd
df=pd.DataFrame({'grade':['A','A','A','A','B','B','C','D','D'],
                 'Age':[18,18,18,19,19,20,18,18,19],
                 'Gender':["M",'M','F','F','F','M','F','F','M']})
df
pd.crosstab(index=df['Age'], columns='count')
# Out:
# col_0  count
# Age
# 18         5
# 19         3
# 20         1

# %%
import pandas as pd
df=pd.DataFrame({'grade':['A','A','A','A','B','B','C','D','D'],
                 'Age':[18,18,18,19,19,20,18,18,19],
                 'Gender':["M",'M','F','F','F','M','F','F','M']})
df
pd.crosstab(df['Age'],df['grade'])
# Out:
# grade  A  B  C  D
# Age
# 18     3  0  1  1
# 19     1  1  0  1
# 20     0  1  0  0

# %%
import pandas as pd
df=pd.DataFrame({'grade':['A','A','A','A','B','B','C','D','D'],
                 'Age':[18,18,18,19,19,20,18,18,19],
                 'Gender':["M",'M','F','F','F','M','F','F','M']})
df
pd.crosstab(index=df['Age'], columns=['grade'])
# Out:
# col_0  grade
# Age
# 18         5
# 19         3
# 20         1

# %%
import matplotlib.pyplot as plt
category=['Male','Female']
frequency=[79,27]
plt.bar(category,frequency)
plt.xlabel("Gender")
plt.ylabel('Frequency')
plt.title('Frequency Distribution Plot For Gender')
plt.show()

# %%
import pandas as pd
def findWordLengths(input_string):
  words=input_string.split()
  print(words)
  wordLengths=list(map(len,words))

# %%
import pandas as pd
